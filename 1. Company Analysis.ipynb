# %%
from Helpers import edgar_support
import re

# %% [markdown]
# # Set Up

# %%
edgar_filing_url = "https://www.sec.gov/Archives/edgar/data/1093691/000155837021010611/0001558370-21-010611-index.htm"
base_url, filing_summary_url = edgar_support.convert_filing_to_folder(edgar_filing_url=edgar_filing_url)
slugs = edgar_support.retrieve_face_report_slugs(filing_summary_url)

# %% [markdown]
# # Balance Sheet Analysis

# %%
balance_sheet_url = base_url + "/" + slugs["BS"]
bs = edgar_support.get_clean_table(balance_sheet_url)
bs = bs.pipe(edgar_support.remove_rows_of_zeros)

divisor_caption = [caption for caption in bs["Captions"] if re.search(r"total", caption.lower()) and re.search(r"equity", caption.lower())][0]
bs = edgar_support.common_size_financial_statement(bs, divisor=bs.query("Captions == @divisor_caption").select_dtypes("number").iloc[0])
# Out:
# Unable to clean column - Captions.

# %% [markdown]
# # Income Statement Analysis

# %%
income_statement_url = base_url + "/" + slugs["IS"]
is_df = edgar_support.get_clean_table(income_statement_url)

is_df = is_df.query("~Captions.fillna('').str.contains('\[')") 
is_df = is_df.query("Captions.notnull()")

is_df = is_df.dropna(thresh=len(is_df)*.1, axis=1)
is_df = is_df.pipe(edgar_support.clean_dataframe)
is_df = is_df.pipe(edgar_support.remove_rows_of_zeros)

is_df = is_df.drop_duplicates(subset=["Captions"], keep="first")

is_df = edgar_support.common_size_financial_statement(is_df, divisor=is_df.select_dtypes("number").iloc[0])
# Out:
# Unable to clean column - Captions.
# Unable to clean column - Captions.

# %% [markdown]
# # Cash Flow Analysis

# %%
cash_flow_url = base_url + "/" + slugs["CF"]
cf = edgar_support.get_clean_table(cash_flow_url)
cf = cf.pipe(edgar_support.remove_rows_of_zeros)
cf = edgar_support.common_size_financial_statement(cf, divisor=cf.select_dtypes("number").iloc[0])
# Out:
# Unable to clean column - Captions.

# %% [markdown]
# # Visualizations

# %% [markdown]
# ## Balance Sheet

# %%
bs.style\
    .background_gradient(cmap='Blues', axis=0,)\
    .set_properties(**{'padding': '10px'})\
    .format({col: '{:,.2%}'.format for col in bs.select_dtypes("number").columns })\
# Out:
# <style type="text/css">
# #T_b2a26_row0_col0, #T_b2a26_row1_col0, #T_b2a26_row2_col0, #T_b2a26_row3_col0, #T_b2a26_row4_col0, #T_b2a26_row5_col0, #T_b2a26_row6_col0, #T_b2a26_row7_col0, #T_b2a26_row8_col0, #T_b2a26_row9_col0, #T_b2a26_row10_col0, #T_b2a26_row11_col0, #T_b2a26_row12_col0, #T_b2a26_row13_col0, #T_b2a26_row14_col0, #T_b2a26_row15_col0, #T_b2a26_row16_col0, #T_b2a26_row17_col0, #T_b2a26_row18_col0, #T_b2a26_row19_col0, #T_b2a26_row20_col0, #T_b2a26_row21_col0, #T_b2a26_row22_col0, #T_b2a26_row23_col0, #T_b2a26_row24_col0, #T_b2a26_row25_col0, #T_b2a26_row26_col0, #T_b2a26_row27_col0, #T_b2a26_row28_col0, #T_b2a26_row29_col0, #T_b2a26_row30_col0, #T_b2a26_row31_col0, #T_b2a26_row32_col0, #T_b2a26_row33_col0, #T_b2a26_row34_col0, #T_b2a26_row35_col0, #T_b2a26_row36_col0, #T_b2a26_row37_col0, #T_b2a26_row38_col0, #T_b2a26_row39_col0, #T_b2a26_row40_col0 {
#   padding: 10px;
# }
# #T_b2a26_row0_col1 {
#   background-color: #519ccc;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b2a26_row0_col2 {
#   background-color: #4997c9;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b2a26_row1_col1, #T_b2a26_row4_col1, #T_b2a26_row12_col1, #T_b2a26_row13_col1, #T_b2a26_row17_col1 {
#   background-color: #c8dcf0;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row1_col2, #T_b2a26_row9_col2, #T_b2a26_row12_col2, #T_b2a26_row13_col2 {
#   background-color: #9fcae1;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row2_col1, #T_b2a26_row4_col2, #T_b2a26_row6_col2, #T_b2a26_row14_col2, #T_b2a26_row17_col2, #T_b2a26_row18_col2, #T_b2a26_row32_col2 {
#   background-color: #a0cbe2;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row2_col2, #T_b2a26_row3_col2, #T_b2a26_row10_col2, #T_b2a26_row15_col2, #T_b2a26_row21_col2, #T_b2a26_row28_col2, #T_b2a26_row34_col2, #T_b2a26_row36_col2 {
#   background-color: #a3cce3;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row3_col1, #T_b2a26_row9_col1, #T_b2a26_row27_col1, #T_b2a26_row31_col1 {
#   background-color: #c7dcef;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row5_col1 {
#   background-color: #c4daee;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row5_col2, #T_b2a26_row29_col2, #T_b2a26_row31_col2 {
#   background-color: #99c7e0;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row6_col1, #T_b2a26_row14_col1, #T_b2a26_row18_col1, #T_b2a26_row19_col1, #T_b2a26_row22_col1, #T_b2a26_row23_col1, #T_b2a26_row24_col1, #T_b2a26_row26_col1, #T_b2a26_row32_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row7_col1, #T_b2a26_row16_col2, #T_b2a26_row40_col2 {
#   background-color: #1b69af;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b2a26_row7_col2 {
#   background-color: #3989c1;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b2a26_row8_col1 {
#   background-color: #bfd8ed;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row8_col2 {
#   background-color: #91c3de;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row10_col1, #T_b2a26_row15_col1, #T_b2a26_row20_col1, #T_b2a26_row21_col1, #T_b2a26_row28_col1, #T_b2a26_row34_col1, #T_b2a26_row36_col1 {
#   background-color: #caddf0;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row11_col1, #T_b2a26_row29_col1 {
#   background-color: #c7dbef;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row11_col2, #T_b2a26_row27_col2 {
#   background-color: #9cc9e1;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row16_col1, #T_b2a26_row40_col1 {
#   background-color: #09529d;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b2a26_row19_col2, #T_b2a26_row20_col2, #T_b2a26_row22_col2, #T_b2a26_row23_col2, #T_b2a26_row24_col2, #T_b2a26_row26_col2 {
#   background-color: #a1cbe2;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row25_col1 {
#   background-color: #c3daee;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row25_col2 {
#   background-color: #94c4df;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row30_col1 {
#   background-color: #c6dbef;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row30_col2 {
#   background-color: #9dcae1;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row33_col1 {
#   background-color: #aacfe5;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row33_col2 {
#   background-color: #69add5;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b2a26_row35_col1, #T_b2a26_row35_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b2a26_row37_col1, #T_b2a26_row37_col2 {
#   background-color: #f7fbff;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row38_col1 {
#   background-color: #cadef0;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row38_col2 {
#   background-color: #a5cde3;
#   color: #000000;
#   padding: 10px;
# }
# #T_b2a26_row39_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b2a26_row39_col2 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
#   padding: 10px;
# }
# </style>
# <table id="T_b2a26_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Captions</th>
#       <th class="col_heading level0 col1" >Jun. 30, 2021</th>
#       <th class="col_heading level0 col2" >Dec. 31, 2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2a26_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b2a26_row0_col0" class="data row0 col0" >Cash and cash equivalents</td>
#       <td id="T_b2a26_row0_col1" class="data row0 col1" >65.42%</td>
#       <td id="T_b2a26_row0_col2" class="data row0 col2" >89.47%</td>
#     </tr>
#     <tr>
#       <th id="T_b2a26_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b2a26_row1_col0" class="data row1 col0" >Restricted cash</td>
#       <td id="T_b2a26_row1_col1" class="data row1 col1" >1.69%</td>
#       <td id="T_b2a26_row1_col2" class="data row1 col2" >4.37%</td>
#     </tr>
#     <tr>
#       <th id="T_b2a26_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b2a26_row2_col0" class="data row2 col0" >Available-for-sale securities, at fair value (amortized cost $1,244,618 and allowance for credit losses of $0 at June 30, 2021)</td>
#       <td id="T_b2a26_row2_col1" class="data row2 col1" >25.72%</td>
#       <td id="T_b2a26_row2_col2" class="data row2 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_b2a26_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b2a26_row3_col0" class="data row3 col0" >Equity securities</td>
#       <td id="T_b2a26_row3_col1" class="data row3 col1" >2.49%</td>
#       <td id="T_b2a26_row3_col2" class="data row3 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_b2a26_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_b2a26_row4_col0" class="data row4 col0" >Accounts receivable</td>
#       <td id="T_b2a26_row4_col1" class="data row4 col1" >1.89%</td>
#       <td id="T_b2a26_row4_col2" class="data row4 col2" >2.93%</td>
#     </tr>
#     <tr>
#       <th id="T_b2a26_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_b2a26_row5_col0" class="data row5 col0" >Inventory</td>
#       <td id="T_b2a26_row5_col1" class="data row5 col1" >4.34%</td>
#       <td id="T_b2a26_row5_col2" class="data row5 col2" >9.50%</td>
#     </tr>
#     <tr>
#       <th id="T_b2a26_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_b2a26_row6_col0" class="data row6 col0" >Prepaid expenses and other current assets</td>
#       <td id="T_b2a26_row6_col1" class="data row6 col1" >1.25%</td>
#       <td id="T_b2a26_row6_col2" class="data row6 col2" >3.02%</td>
#     </tr>
#     <tr>
#       <th id="T_b2a26_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_b2a26_row7_col0" class="data row7 col0" >Total current assets</td>
#       <td id="T_b2a26_row7_col1" class="data row7 col1" >102.81%</td>
#       <td id="T_b2a26_row7_col2" class="data row7 col2" >109.29%</td>
#     </tr>
#     <tr>
#       <th id="T_b2a26_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_b2a26_row8_col0" class="data row8 col0" >Restricted cash</td>
#       <td id="T_b2a26_row8_col1" class="data row8 col1" >7.20%</td>
#       <td id="T_b2a26_row8_col2" class="data row8 col2" >17.58%</td>
#     </tr>
#     <tr>
#       <th id="T_b2a26_level0_row9" class="row_heading level0 row9" >10</th>

# %% [markdown]
# ## Income Statement

# %%
is_df.style\
    .background_gradient(cmap='Blues', axis=0,)\
    .set_properties(**{'padding': '10px'})\
    .hide_index()\
    .format({col: '{:,.2%}'.format for col in is_df.select_dtypes("number").columns })\
# Out:
# <style type="text/css">
# #T_105dd_row0_col0, #T_105dd_row1_col0, #T_105dd_row2_col0, #T_105dd_row3_col0, #T_105dd_row4_col0, #T_105dd_row5_col0, #T_105dd_row6_col0, #T_105dd_row7_col0, #T_105dd_row8_col0, #T_105dd_row9_col0, #T_105dd_row10_col0, #T_105dd_row11_col0, #T_105dd_row12_col0, #T_105dd_row13_col0, #T_105dd_row14_col0, #T_105dd_row15_col0, #T_105dd_row16_col0, #T_105dd_row17_col0, #T_105dd_row18_col0, #T_105dd_row19_col0 {
#   padding: 10px;
# }
# #T_105dd_row0_col1, #T_105dd_row0_col2, #T_105dd_row0_col3, #T_105dd_row0_col4, #T_105dd_row1_col1, #T_105dd_row1_col2, #T_105dd_row1_col3, #T_105dd_row1_col4, #T_105dd_row2_col1, #T_105dd_row2_col2, #T_105dd_row2_col3, #T_105dd_row2_col4, #T_105dd_row3_col1, #T_105dd_row3_col2, #T_105dd_row3_col3, #T_105dd_row3_col4, #T_105dd_row4_col1, #T_105dd_row4_col2, #T_105dd_row4_col3, #T_105dd_row4_col4, #T_105dd_row5_col1, #T_105dd_row5_col2, #T_105dd_row5_col3, #T_105dd_row5_col4, #T_105dd_row6_col1, #T_105dd_row6_col2, #T_105dd_row6_col3, #T_105dd_row6_col4, #T_105dd_row7_col1, #T_105dd_row7_col2, #T_105dd_row7_col3, #T_105dd_row7_col4, #T_105dd_row8_col1, #T_105dd_row8_col2, #T_105dd_row8_col3, #T_105dd_row8_col4, #T_105dd_row9_col1, #T_105dd_row9_col2, #T_105dd_row9_col3, #T_105dd_row9_col4, #T_105dd_row10_col1, #T_105dd_row10_col2, #T_105dd_row10_col3, #T_105dd_row10_col4, #T_105dd_row11_col1, #T_105dd_row11_col2, #T_105dd_row11_col3, #T_105dd_row11_col4, #T_105dd_row12_col1, #T_105dd_row12_col2, #T_105dd_row12_col3, #T_105dd_row12_col4, #T_105dd_row13_col1, #T_105dd_row13_col2, #T_105dd_row13_col3, #T_105dd_row13_col4, #T_105dd_row14_col1, #T_105dd_row14_col2, #T_105dd_row14_col3, #T_105dd_row14_col4, #T_105dd_row15_col1, #T_105dd_row15_col2, #T_105dd_row15_col3, #T_105dd_row15_col4, #T_105dd_row16_col1, #T_105dd_row16_col2, #T_105dd_row16_col3, #T_105dd_row16_col4, #T_105dd_row17_col1, #T_105dd_row17_col2, #T_105dd_row17_col3, #T_105dd_row17_col4, #T_105dd_row18_col1, #T_105dd_row18_col2, #T_105dd_row18_col3, #T_105dd_row18_col4 {
#   background-color: #f7fbff;
#   color: #000000;
#   padding: 10px;
# }
# #T_105dd_row19_col1, #T_105dd_row19_col2, #T_105dd_row19_col3, #T_105dd_row19_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   padding: 10px;
# }
# </style>
# <table id="T_105dd_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Captions</th>
#       <th class="col_heading level0 col1" >3 Months Ended
# Jun. 30, 2021</th>
#       <th class="col_heading level0 col2" >3 Months Ended
# Jun. 30, 2020</th>
#       <th class="col_heading level0 col3" >6 Months Ended
# Jun. 30, 2021</th>
#       <th class="col_heading level0 col4" >6 Months Ended
# Jun. 30, 2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_105dd_row0_col0" class="data row0 col0" >Net revenue</td>
#       <td id="T_105dd_row0_col1" class="data row0 col1" >100.00%</td>
#       <td id="T_105dd_row0_col2" class="data row0 col2" >100.00%</td>
#       <td id="T_105dd_row0_col3" class="data row0 col3" >100.00%</td>
#       <td id="T_105dd_row0_col4" class="data row0 col4" >100.00%</td>
#     </tr>
#     <tr>
#       <td id="T_105dd_row1_col0" class="data row1 col0" >Total cost of revenue</td>
#       <td id="T_105dd_row1_col1" class="data row1 col1" >132.35%</td>
#       <td id="T_105dd_row1_col2" class="data row1 col2" >100.02%</td>
#       <td id="T_105dd_row1_col3" class="data row1 col3" >126.70%</td>
#       <td id="T_105dd_row1_col4" class="data row1 col4" >108.93%</td>
#     </tr>
#     <tr>
#       <td id="T_105dd_row2_col0" class="data row2 col0" >Gross loss</td>
#       <td id="T_105dd_row2_col1" class="data row2 col1" >-32.35%</td>
#       <td id="T_105dd_row2_col2" class="data row2 col2" >-0.02%</td>
#       <td id="T_105dd_row2_col3" class="data row2 col3" >-26.70%</td>
#       <td id="T_105dd_row2_col4" class="data row2 col4" >-8.93%</td>
#     </tr>
#     <tr>
#       <td id="T_105dd_row3_col0" class="data row3 col0" >Research and development</td>
#       <td id="T_105dd_row3_col1" class="data row3 col1" >9.03%</td>
#       <td id="T_105dd_row3_col2" class="data row3 col2" >7.17%</td>
#       <td id="T_105dd_row3_col3" class="data row3 col3" >10.68%</td>
#       <td id="T_105dd_row3_col4" class="data row3 col4" >8.87%</td>
#     </tr>
#     <tr>
#       <td id="T_105dd_row4_col0" class="data row4 col0" >Selling, general and administrative</td>
#       <td id="T_105dd_row4_col1" class="data row4 col1" >31.03%</td>
#       <td id="T_105dd_row4_col2" class="data row4 col2" >31.83%</td>
#       <td id="T_105dd_row4_col3" class="data row4 col3" >32.69%</td>
#       <td id="T_105dd_row4_col4" class="data row4 col4" >30.10%</td>
#     </tr>
#     <tr>
#       <td id="T_105dd_row5_col0" class="data row5 col0" >Change in fair value of contingent consideration</td>
#       <td id="T_105dd_row5_col1" class="data row5 col1" >-0.45%</td>
#       <td id="T_105dd_row5_col2" class="data row5 col2" >0.00%</td>
#       <td id="T_105dd_row5_col3" class="data row5 col3" >0.12%</td>
#       <td id="T_105dd_row5_col4" class="data row5 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <td id="T_105dd_row6_col0" class="data row6 col0" >Total operating expenses</td>
#       <td id="T_105dd_row6_col1" class="data row6 col1" >39.61%</td>
#       <td id="T_105dd_row6_col2" class="data row6 col2" >39.00%</td>
#       <td id="T_105dd_row6_col3" class="data row6 col3" >43.48%</td>
#       <td id="T_105dd_row6_col4" class="data row6 col4" >38.97%</td>
#     </tr>
#     <tr>
#       <td id="T_105dd_row7_col0" class="data row7 col0" >Operating loss</td>
#       <td id="T_105dd_row7_col1" class="data row7 col1" >-71.96%</td>
#       <td id="T_105dd_row7_col2" class="data row7 col2" >-39.02%</td>
#       <td id="T_105dd_row7_col3" class="data row7 col3" >-70.18%</td>
#       <td id="T_105dd_row7_col4" class="data row7 col4" >-47.90%</td>
#     </tr>
#     <tr>
#       <td id="T_105dd_row8_col0" class="data row8 col0" >Interest</td>
#       <td id="T_105dd_row8_col1" class="data row8 col1" >-8.24%</td>
#       <td id="T_105dd_row8_col2" class="data row8 col2" >-19.66%</td>
#       <td id="T_105dd_row8_col3" class="data row8 col3" >-11.47%</td>
#       <td id="T_105dd_row8_col4" class="data row8 col4" >-23.12%</td>
#     </tr>
#     <tr>
#       <td id="T_105dd_row9_col0" class="data row9 col0" >Other expense, net</td>
#       <td id="T_105dd_row9_col1" class="data row9 col1" >-0.06%</td>
#       <td id="T_105dd_row9_col2" class="data row9 col2" >-0.14%</td>
#       <td id="T_105dd_row9_col3" class="data row9 col3" >-0.14%</td>
#       <td id="T_105dd_row9_col4" class="data row9 col4" >-0.14%</td>
#     </tr>
#     <tr>
#       <td id="T_105dd_row10_col0" class="data row10 col0" >Realized gain on investments, net</td>
#       <td id="T_105dd_row10_col1" class="data row10 col1" >0.01%</td>
#       <td id="T_105dd_row10_col2" class="data row10 col2" >0.00%</td>
#       <td id="T_105dd_row10_col3" class="data row10 col3" >0.01%</td>
#       <td id="T_105dd_row10_col4" class="data row10 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <td id="T_105dd_row11_col0" class="data row11 col0" >Change in fair value of equity securities</td>
#       <td id="T_105dd_row11_col1" class="data row11 col1" >0.26%</td>
#       <td id="T_105dd_row11_col2" class="data row11 col2" >0.00%</td>
#       <td id="T_105dd_row11_col3" class="data row11 col3" >0.16%</td>
#       <td id="T_105dd_row11_col4" class="data row11 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <td id="T_105dd_row12_col0" class="data row12 col0" >Gain on extinguishment of debt</td>
#       <td id="T_105dd_row12_col1" class="data row12 col1" >0.00%</td>
#       <td id="T_105dd_row12_col2" class="data row12 col2" >19.45%</td>
#       <td id="T_105dd_row12_col3" class="data row12 col3" >0.00%</td>
#       <td id="T_105dd_row12_col4" class="data row12 col4" >12.15%</td>
#     </tr>
#     <tr>
#       <td id="T_105dd_row13_col0" class="data row13 col0" >Loss before income taxes</td>
#       <td id="T_105dd_row13_col1" class="data row13 col1" >-79.99%</td>
#       <td id="T_105dd_row13_col2" class="data row13 col2" >-39.37%</td>
#       <td id="T_105dd_row13_col3" class="data row13 col3" >-81.61%</td>
#       <td

# %% [markdown]
# ## Cash Flow

# %%
cf.style\
    .background_gradient(cmap='RdBu', axis=0,)\
    .set_properties(**{'padding': '10px'})\
    .format({col: '{:,.2%}'.format for col in cf.select_dtypes("number").columns })
# Out:
# <style type="text/css">
# #T_41409_row0_col0, #T_41409_row1_col0, #T_41409_row2_col0, #T_41409_row3_col0, #T_41409_row4_col0, #T_41409_row5_col0, #T_41409_row6_col0, #T_41409_row7_col0, #T_41409_row8_col0, #T_41409_row9_col0, #T_41409_row10_col0, #T_41409_row11_col0, #T_41409_row12_col0, #T_41409_row13_col0, #T_41409_row14_col0, #T_41409_row15_col0, #T_41409_row16_col0, #T_41409_row17_col0, #T_41409_row18_col0, #T_41409_row19_col0, #T_41409_row20_col0, #T_41409_row21_col0, #T_41409_row22_col0, #T_41409_row23_col0, #T_41409_row24_col0, #T_41409_row25_col0, #T_41409_row26_col0, #T_41409_row27_col0, #T_41409_row28_col0, #T_41409_row29_col0, #T_41409_row30_col0, #T_41409_row31_col0, #T_41409_row32_col0, #T_41409_row33_col0, #T_41409_row34_col0, #T_41409_row35_col0, #T_41409_row36_col0, #T_41409_row37_col0, #T_41409_row38_col0, #T_41409_row39_col0, #T_41409_row40_col0, #T_41409_row41_col0, #T_41409_row42_col0, #T_41409_row43_col0, #T_41409_row44_col0, #T_41409_row45_col0, #T_41409_row46_col0, #T_41409_row47_col0 {
#   padding: 10px;
# }
# #T_41409_row0_col1, #T_41409_row18_col3, #T_41409_row21_col2 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row0_col2 {
#   background-color: #e98b6e;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row0_col3 {
#   background-color: #bd2d35;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row1_col1, #T_41409_row2_col1, #T_41409_row3_col1, #T_41409_row4_col1, #T_41409_row5_col1, #T_41409_row6_col1, #T_41409_row7_col1, #T_41409_row8_col1, #T_41409_row9_col1, #T_41409_row10_col1, #T_41409_row11_col1, #T_41409_row12_col1, #T_41409_row13_col1, #T_41409_row14_col1, #T_41409_row15_col1, #T_41409_row16_col1, #T_41409_row17_col1, #T_41409_row18_col1, #T_41409_row19_col1, #T_41409_row20_col1, #T_41409_row21_col1, #T_41409_row22_col1, #T_41409_row23_col1, #T_41409_row24_col1, #T_41409_row25_col1, #T_41409_row26_col1, #T_41409_row27_col1, #T_41409_row28_col1, #T_41409_row29_col1, #T_41409_row30_col1, #T_41409_row31_col1, #T_41409_row32_col1, #T_41409_row33_col1, #T_41409_row34_col1, #T_41409_row35_col1, #T_41409_row36_col1, #T_41409_row37_col1, #T_41409_row38_col1, #T_41409_row39_col1, #T_41409_row40_col1, #T_41409_row42_col1, #T_41409_row43_col1, #T_41409_row44_col1, #T_41409_row45_col1, #T_41409_row46_col1, #T_41409_row47_col1 {
#   background-color: #790622;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row1_col2, #T_41409_row2_col2, #T_41409_row4_col2, #T_41409_row5_col2, #T_41409_row6_col2, #T_41409_row7_col2, #T_41409_row8_col2, #T_41409_row9_col2, #T_41409_row10_col2, #T_41409_row11_col2, #T_41409_row12_col2, #T_41409_row16_col2, #T_41409_row24_col2, #T_41409_row28_col2, #T_41409_row29_col2, #T_41409_row30_col2, #T_41409_row31_col2, #T_41409_row32_col2, #T_41409_row34_col2, #T_41409_row38_col2, #T_41409_row42_col2, #T_41409_row43_col2, #T_41409_row45_col2, #T_41409_row47_col2 {
#   background-color: #f2a17f;
#   color: #000000;
#   padding: 10px;
# }
# #T_41409_row1_col3 {
#   background-color: #e17860;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row2_col3, #T_41409_row45_col3 {
#   background-color: #de735c;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row3_col2, #T_41409_row17_col2, #T_41409_row26_col2, #T_41409_row36_col2, #T_41409_row46_col2 {
#   background-color: #f3a481;
#   color: #000000;
#   padding: 10px;
# }
# #T_41409_row3_col3, #T_41409_row5_col3, #T_41409_row6_col3, #T_41409_row44_col3 {
#   background-color: #e27b62;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row4_col3, #T_41409_row15_col3 {
#   background-color: #d6604d;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row7_col3, #T_41409_row13_col3 {
#   background-color: #d25849;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row8_col3, #T_41409_row9_col3, #T_41409_row10_col3, #T_41409_row11_col3, #T_41409_row12_col3, #T_41409_row21_col3, #T_41409_row22_col3, #T_41409_row23_col3, #T_41409_row26_col3, #T_41409_row27_col3, #T_41409_row38_col3, #T_41409_row43_col3, #T_41409_row46_col3, #T_41409_row47_col3 {
#   background-color: #dd7059;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row13_col2, #T_41409_row36_col3 {
#   background-color: #ef9979;
#   color: #000000;
#   padding: 10px;
# }
# #T_41409_row14_col2 {
#   background-color: #ee9677;
#   color: #000000;
#   padding: 10px;
# }
# #T_41409_row14_col3 {
#   background-color: #c43b3c;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row15_col2, #T_41409_row20_col2, #T_41409_row33_col2, #T_41409_row35_col2 {
#   background-color: #f19e7d;
#   color: #000000;
#   padding: 10px;
# }
# #T_41409_row16_col3, #T_41409_row17_col3 {
#   background-color: #df765e;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row18_col2 {
#   background-color: #e48066;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row19_col2 {
#   background-color: #f09c7b;
#   color: #000000;
#   padding: 10px;
# }
# #T_41409_row19_col3 {
#   background-color: #db6b55;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row20_col3 {
#   background-color: #da6853;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row22_col2 {
#   background-color: #f8bda1;
#   color: #000000;
#   padding: 10px;
# }
# #T_41409_row23_col2 {
#   background-color: #eb9172;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row24_col3 {
#   background-color: #be3036;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row25_col2 {
#   background-color: #730421;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row25_col3 {
#   background-color: #b61f2e;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row27_col2, #T_41409_row37_col2, #T_41409_row41_col1, #T_41409_row41_col2, #T_41409_row41_col3 {
#   background-color: #053061;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row28_col3 {
#   background-color: #e8896c;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row29_col3 {
#   background-color: #b8d8e9;
#   color: #000000;
#   padding: 10px;
# }
# #T_41409_row30_col3 {
#   background-color: #870a24;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row31_col3 {
#   background-color: #d35a4a;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row32_col3 {
#   background-color: #ec9374;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row33_col3 {
#   background-color: #cf5246;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row34_col3 {
#   background-color: #f6b394;
#   color: #000000;
#   padding: 10px;
# }
# #T_41409_row35_col3 {
#   background-color: #d7634f;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row37_col3 {
#   background-color: #d2e6f0;
#   color: #000000;
#   padding: 10px;
# }
# #T_41409_row39_col2 {
#   background-color: #a0cce2;
#   color: #000000;
#   padding: 10px;
# }
# #T_41409_row39_col3 {
#   background-color: #e58368;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row40_col2 {
#   background-color: #c7e0ed;
#   color: #000000;
#   padding: 10px;
# }
# #T_41409_row40_col3 {
#   background-color: #0d3f76;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row42_col3 {
#   background-color: #e37e64;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_41409_row44_col2 {
#   background-color: #f4a683;
#   color: #000000;
#   padding: 10px;
# }
# </style>
# <table id="T_41409_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Captions</th>
#       <th class="col_heading level0 col1" >3 Months Ended
# Jun. 30, 2021</th>
#       <th class="col_heading level0 col2" >6 Months Ended
# Jun. 30, 2021</th>
#       <th class="col_heading level0 col3" >6 Months Ended
# Jun. 30, 2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41409_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_41409_row0_col0" class="data row0 col0" >Net loss attributable to the Company</td>
#       <td id="T_41409_row0_col1" class="data row0 col1" >-100.00%</td>
#       <td id="T_41409_row0_col2" class="data row0 col2" >-100.00%</td>
#       <td id="T_41409_row0_col3" class="data row0 col3" >-100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_41409_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_41409_row1_col0" class="data row1 col0" >Depreciation of long-lived assets</td>
#       <td id="T_41409_row1_col1" class="data row1 col1" >0.00%</td>
#       <td id="T_41409_row1_col2" class="data row1 col2" >6.06%</td>
#       <td id="T
