# %%
from Helpers.CompanyFiling import Filing
import re

# %% [markdown]
# # Set Up

# %%
edgar_filing_url = "https://www.sec.gov/Archives/edgar/data/1617640/000161764021000055/z-20210630.htm"
filing = Filing.Filing(edgar_filing_url)

# %% [markdown]
# # Balance Sheet Analysis

# %%
bs, styled_bs = filing.get_balance_sheet(commonsize=True)
# Out:
# in Thousands
# Unable to clean column - Captions.

# %% [markdown]
# # Income Statement Analysis

# %%
is_, styled_is = filing.get_income_statement(commonsize=True)
# Out:
# in Thousands
# Unable to clean column - Captions.
# Unable to clean column - Captions.

# %% [markdown]
# # Cash Flow Analysis

# %%
cf, styled_cf = filing.get_cash_flow(commonsize=True)
# Out:
# in ones
# Unable to clean column - Captions.

# %% [markdown]
# # Visualizations

# %% [markdown]
# ## Balance Sheet

# %%
styled_bs
# Out:
# <style type="text/css">
# #T_b5a33_row0_col0, #T_b5a33_row1_col0, #T_b5a33_row2_col0, #T_b5a33_row3_col0, #T_b5a33_row4_col0, #T_b5a33_row5_col0, #T_b5a33_row6_col0, #T_b5a33_row7_col0, #T_b5a33_row8_col0, #T_b5a33_row9_col0, #T_b5a33_row10_col0, #T_b5a33_row11_col0, #T_b5a33_row12_col0, #T_b5a33_row13_col0, #T_b5a33_row14_col0, #T_b5a33_row15_col0, #T_b5a33_row16_col0, #T_b5a33_row17_col0, #T_b5a33_row18_col0, #T_b5a33_row19_col0, #T_b5a33_row20_col0, #T_b5a33_row21_col0, #T_b5a33_row22_col0, #T_b5a33_row23_col0, #T_b5a33_row24_col0, #T_b5a33_row25_col0, #T_b5a33_row26_col0, #T_b5a33_row27_col0, #T_b5a33_row28_col0, #T_b5a33_row29_col0, #T_b5a33_row30_col0, #T_b5a33_row31_col0, #T_b5a33_row32_col0, #T_b5a33_row33_col0, #T_b5a33_row34_col0 {
#   padding: 10px;
# }
# #T_b5a33_row0_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b5a33_row0_col2 {
#   background-color: #add0e6;
#   color: #000000;
#   padding: 10px;
# }
# #T_b5a33_row1_col1 {
# ...

# %% [markdown]
# ## Income Statement

# %%
styled_is
# Out:
# <style type="text/css">
# #T_d18af_row0_col0, #T_d18af_row1_col0, #T_d18af_row2_col0, #T_d18af_row3_col0, #T_d18af_row4_col0, #T_d18af_row5_col0, #T_d18af_row6_col0, #T_d18af_row7_col0, #T_d18af_row8_col0, #T_d18af_row9_col0, #T_d18af_row10_col0, #T_d18af_row11_col0, #T_d18af_row12_col0, #T_d18af_row13_col0, #T_d18af_row14_col0, #T_d18af_row15_col0, #T_d18af_row16_col0, #T_d18af_row17_col0, #T_d18af_row18_col0, #T_d18af_row19_col0 {
#   padding: 10px;
# }
# #T_d18af_row0_col1, #T_d18af_row0_col2, #T_d18af_row0_col3, #T_d18af_row0_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_d18af_row1_col1, #T_d18af_row1_col3 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_d18af_row1_col2 {
#   background-color: #3686c0;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_d18af_row1_col4 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_d18af_row2_col1, #T_d18af_row2_col2 {
# ...

# %% [markdown]
# ## Cash Flow

# %%
styled_cf
# Out:
# <style type="text/css">
# #T_595c5_row0_col0, #T_595c5_row1_col0, #T_595c5_row2_col0, #T_595c5_row3_col0, #T_595c5_row4_col0, #T_595c5_row5_col0, #T_595c5_row6_col0, #T_595c5_row7_col0, #T_595c5_row8_col0, #T_595c5_row9_col0, #T_595c5_row10_col0, #T_595c5_row11_col0, #T_595c5_row12_col0, #T_595c5_row13_col0, #T_595c5_row14_col0, #T_595c5_row15_col0, #T_595c5_row16_col0, #T_595c5_row17_col0, #T_595c5_row18_col0, #T_595c5_row19_col0, #T_595c5_row20_col0, #T_595c5_row21_col0, #T_595c5_row22_col0, #T_595c5_row23_col0, #T_595c5_row24_col0, #T_595c5_row25_col0, #T_595c5_row26_col0, #T_595c5_row27_col0, #T_595c5_row28_col0, #T_595c5_row29_col0, #T_595c5_row30_col0, #T_595c5_row31_col0, #T_595c5_row32_col0, #T_595c5_row33_col0, #T_595c5_row34_col0, #T_595c5_row35_col0, #T_595c5_row36_col0, #T_595c5_row37_col0, #T_595c5_row38_col0, #T_595c5_row39_col0, #T_595c5_row40_col0, #T_595c5_row41_col0, #T_595c5_row42_col0, #T_595c5_row43_col0, #T_595c5_row44_col0, #T_595c5_row45_col0 {
# ...
