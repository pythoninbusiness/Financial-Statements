# %% [markdown]
# # Common Size Balance Sheet

# %% [markdown]
# **Purpose**: The purpose of this notebook is to obtain the Balance Sheet table from a Company filing (10-Q, 10-K) using the filing url. Edgar nicely provides just the table, which can be easily extracted using Pandas for further analysis. We want to convert the statement to a common size statement by dividing each year by the Total Equity amount. As a result, we can see each caption relative to the overall Total Equity.

# %% [markdown]
# ## Imports

# %%
from Helpers import edgar_support
import re

# %% [markdown]
# ## Set Up

# %% [markdown]
# Get the URL for the edgar filing. This is the "index-htm" page edgar directs you to when you click on a quarterly/annual report. We sould convert the url to redirect us to the folder structure of the filing package. Once inside, the folder has a file called the "FilingSummary.xml" which describes each item in the folder. We will scrape the filing summary to identify the file the statement is stored in.

# %%
edgar_filing_url = "https://www.sec.gov/Archives/edgar/data/1617640/000161764021000012/0001617640-21-000012-index.html"
base_url, filing_summary_url = edgar_support.convert_filing_to_folder(edgar_filing_url=edgar_filing_url)
slugs = edgar_support.retrieve_face_report_slugs(filing_summary_url)
balance_sheet_url = base_url + "/" + slugs["BS"]

# %% [markdown]
# ## Clean

# %% [markdown]
# In order to analyze the statement, we first use pandas to read the table form the URL we discovered above. We clean the dataframe by renaming the first column header,  converting the multi-index columns to be a single index, and converting the data types to be numeric. Next, we remove rows where all numeric columns are all missing.
#
# Lastly, we return the common size statement by dividng by the Total Equity row.

# %%
bs = edgar_support.get_clean_table(balance_sheet_url)
bs = bs.pipe(edgar_support.remove_rows_of_zeros)

divisor_caption = [caption for caption in bs["Captions"] if re.search(r"total", caption.lower()) and re.search(r"equity", caption.lower())][0]
bs = edgar_support.common_size_financial_statement(bs, divisor=bs.query("Captions == @divisor_caption").select_dtypes("number").iloc[0])
# Out:
# Unable to clean column - Captions.

# %% [markdown]
# ## Visualize

# %% [markdown]
# We use pandas styler objects to add padding, add background colors, and format our numbers.

# %%
bs.style\
    .background_gradient(cmap='Blues', axis=0,)\
    .set_properties(**{'padding': '10px'})\
    .format({col: '{:,.2%}'.format for col in bs.select_dtypes("number").columns })\
# Out:
# <style type="text/css">
# #T_57561_row0_col0, #T_57561_row1_col0, #T_57561_row2_col0, #T_57561_row3_col0, #T_57561_row4_col0, #T_57561_row5_col0, #T_57561_row6_col0, #T_57561_row7_col0, #T_57561_row8_col0, #T_57561_row9_col0, #T_57561_row10_col0, #T_57561_row11_col0, #T_57561_row12_col0, #T_57561_row13_col0, #T_57561_row14_col0, #T_57561_row15_col0, #T_57561_row16_col0, #T_57561_row17_col0, #T_57561_row18_col0, #T_57561_row19_col0, #T_57561_row20_col0, #T_57561_row21_col0, #T_57561_row22_col0, #T_57561_row23_col0, #T_57561_row24_col0, #T_57561_row25_col0, #T_57561_row26_col0, #T_57561_row27_col0, #T_57561_row28_col0, #T_57561_row29_col0, #T_57561_row30_col0, #T_57561_row31_col0, #T_57561_row32_col0, #T_57561_row33_col0 {
#   padding: 10px;
# }
# #T_57561_row0_col1 {
#   background-color: #add0e6;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row0_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row1_col1 {
#   background-color: #99c7e0;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row1_col2, #T_57561_row23_col1 {
#   background-color: #b0d2e7;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row2_col1, #T_57561_row8_col1, #T_57561_row13_col2, #T_57561_row15_col2, #T_57561_row17_col1, #T_57561_row19_col1, #T_57561_row20_col2, #T_57561_row24_col2, #T_57561_row27_col2, #T_57561_row31_col2, #T_57561_row32_col2, #T_57561_row33_col2 {
#   background-color: #dce9f6;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row2_col2, #T_57561_row5_col2 {
#   background-color: #dae8f6;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row3_col1, #T_57561_row22_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row3_col2, #T_57561_row5_col1, #T_57561_row6_col1, #T_57561_row8_col2, #T_57561_row12_col1, #T_57561_row16_col1, #T_57561_row17_col2, #T_57561_row19_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row4_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row4_col2 {
#   background-color: #c4daee;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row6_col2, #T_57561_row16_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row7_col1 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_57561_row7_col2 {
#   background-color: #4090c5;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_57561_row9_col1, #T_57561_row10_col1, #T_57561_row22_col1 {
#   background-color: #d9e7f5;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row9_col2 {
#   background-color: #d7e6f5;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row10_col2, #T_57561_row12_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row11_col1 {
#   background-color: #a3cce3;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row11_col2 {
#   background-color: #8dc1dd;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row13_col1, #T_57561_row15_col1, #T_57561_row20_col1, #T_57561_row24_col1 {
#   background-color: #dceaf6;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row14_col1, #T_57561_row14_col2, #T_57561_row30_col1, #T_57561_row30_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_57561_row18_col1 {
#   background-color: #cee0f2;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row18_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row21_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row21_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row23_col2 {
#   background-color: #a5cde3;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row25_col1 {
#   background-color: #7fb9da;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row25_col2 {
#   background-color: #65aad4;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_57561_row26_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_57561_row26_col2 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_57561_row27_col1, #T_57561_row31_col1, #T_57561_row32_col1, #T_57561_row33_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row28_col1, #T_57561_row28_col2 {
#   background-color: #f7fbff;
#   color: #000000;
#   padding: 10px;
# }
# #T_57561_row29_col1 {
#   background-color: #3383be;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_57561_row29_col2 {
#   background-color: #4493c7;
#   color: #f1f1f1;
#   padding: 10px;
# }
# </style>
# <table id="T_57561_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Captions</th>
#       <th class="col_heading level0 col1" >Dec. 31, 2020</th>
#       <th class="col_heading level0 col2" >Dec. 31, 2019</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57561_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_57561_row0_col0" class="data row0 col0" >Cash and cash equivalents</td>
#       <td id="T_57561_row0_col1" class="data row0 col1" >35.92%</td>
#       <td id="T_57561_row0_col2" class="data row0 col2" >33.22%</td>
#     </tr>
#     <tr>
#       <th id="T_57561_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_57561_row1_col0" class="data row1 col0" >Short-term investments</td>
#       <td id="T_57561_row1_col1" class="data row1 col1" >46.78%</td>
#       <td id="T_57561_row1_col2" class="data row1 col2" >37.29%</td>
#     </tr>
#     <tr>
#       <th id="T_57561_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_57561_row2_col0" class="data row2 col0" >Accounts receivable, net of allowance for doubtful accounts of $3,427 and $4,522 at December 31, 2020 and 2019, respectively</td>
#       <td id="T_57561_row2_col1" class="data row2 col1" >1.47%</td>
#       <td id="T_57561_row2_col2" class="data row2 col2" >1.95%</td>
#     </tr>
#     <tr>
#       <th id="T_57561_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_57561_row3_col0" class="data row3 col0" >Mortgage loans held for sale</td>
#       <td id="T_57561_row3_col1" class="data row3 col1" >6.98%</td>
#       <td id="T_57561_row3_col2" class="data row3 col2" >1.06%</td>
#     </tr>
#     <tr>
#       <th id="T_57561_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_57561_row4_col0" class="data row4 col0" >Inventory</td>
#       <td id="T_57561_row4_col1" class="data row4 col1" >10.36%</td>
#       <td id="T_57561_row4_col2" class="data row4 col2" >24.35%</td>
#     </tr>
#     <tr>
#       <th id="T_57561_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_57561_row5_col0" class="data row5 col0" >Prepaid expenses and other current assets</td>
#       <td id="T_57561_row5_col1" class="data row5 col1" >1.60%</td>
#       <td id="T_57561_row5_col2" class="data row5 col2" >1.69%</td>
#     </tr>
#     <tr>
#       <th id="T_57561_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_57561_row6_col0" class="data row6 col0" >Restricted cash</td>
#       <td id="T_57561_row6_col1" class="data row6 col1" >1.60%</td>
#       <td id="T_57561_row6_col2" class="data row6 col2" >2.61%</td>
#     </tr>
#     <tr>
#       <th id="T_57561_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_57561_row7_col0" class="data row7 col0" >Total current assets</td>
#       <td id="T_57561_row7_col1" class="data row7 col1" >104.70%</td>
#       <td id="T_57561_row7_col2" class="data row7 col2" >102.18%</td>
#     </tr>
#     <tr>
#       <th id="T_57561_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_57561_row8_col0" class="data row8 col0" >Contract cost assets</td>
#       <td id="T_57561_row8_col1" class="data row8 col1" >1.07%</td>
#       <td id="T_57561_row8_col2" class="data row8 col2" >1.32%</td>
#     </tr>
#     <tr>
#       <th id="T_57561_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_57561_row9_col0" class="data row9 col0" >Property and equipment, net</td>
#       <td id="T_57561_row9_col1" class="data row9 col1" >4.14%</td>
#       <td id="T_57561_row9_col2" class="data row9 col2" >4.96%</td>
#     </tr>
#     <tr>
#       <th id="T_57561_level0_row10" class="row
