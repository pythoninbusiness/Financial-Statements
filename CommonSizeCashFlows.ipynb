# %% [markdown]
# # Common Size Cash Flow

# %% [markdown]
# **Purpose**: The purpose of this notebook is to obtain the Cash Flow table from a Company filing (10-Q, 10-K) using the filing url. Edgar nicely provides just the table, which can be easily extracted using Pandas for further analysis. We want to convert the Cash Flows statement to a common size statement by dividing each year by the Net Income (Loss) amount. As a result, we can identify accounts that have the largest activity, relative to the Company's Net Income (Loss).

# %% [markdown]
# ## Imports

# %%
from Helpers import edgar_support

# %% [markdown]
# ## Set Up

# %% [markdown]
# Get the URL for the edgar filing. This is the "index-htm" page edgar directs you to when you click on a quarterly/annual report. We sould convert the url to redirect us to the folder structure of the filing package. Once inside, the folder has a file called the "FilingSummary.xml" which describes each item in the folder. We will scrape the filing summary to identify the file the Cash Flows statement is stored in.

# %%
edgar_filing_url = "https://www.sec.gov/Archives/edgar/data/1617640/000161764021000012/0001617640-21-000012-index.html"
base_url, filing_summary_url = edgar_support.convert_filing_to_folder(edgar_filing_url=edgar_filing_url)
slugs = edgar_support.retrieve_face_report_slugs(filing_summary_url)
cash_flow_url = base_url + "/" + slugs["CF"]

# %% [markdown]
# ## Clean

# %% [markdown]
# In order to analyze the Cash Flows statement, we first use pandas to read the table form the URL we discovered above. We clean the dataframe by renaming the first column header,  converting the multi-index columns to be a single index, and converting the data types to be numeric. Next, we remove rows where all numeric columns are all missing.
#
# Lastly, we return the common size Cash Flows statement by dividng by the first row of the dataframe, which is where Net Income (Loss) is stored. We can confirm this by looking at the result. Net Income (Loss) in all years are equal to 1.0.

# %%
cf = edgar_support.get_clean_cash_flow(cash_flow_url)
cf = cf.pipe(edgar_support.remove_rows_of_zeros)
cf = edgar_support.common_size_financial_statement(cf, divisor=cf.select_dtypes("number").iloc[0])
# Out:
# Unable to clean column - Captions.

# %% [markdown]
# ## Visualize

# %% [markdown]
# We use pandas styler objects to add padding, add background colors, and format our numbers. As a result, we can easily identify where the Company is getting/spending its cash.

# %%
cf.style\
    .background_gradient(cmap='RdBu', axis=0,)\
    .set_properties(**{'padding': '10px'})\
    .format({col: '{:,.2%}'.format for col in cf.select_dtypes("number").columns })\
# Out:
# <style type="text/css">
# #T_b9e71_row0_col0, #T_b9e71_row1_col0, #T_b9e71_row2_col0, #T_b9e71_row3_col0, #T_b9e71_row4_col0, #T_b9e71_row5_col0, #T_b9e71_row6_col0, #T_b9e71_row7_col0, #T_b9e71_row8_col0, #T_b9e71_row9_col0, #T_b9e71_row10_col0, #T_b9e71_row11_col0, #T_b9e71_row12_col0, #T_b9e71_row13_col0, #T_b9e71_row14_col0, #T_b9e71_row15_col0, #T_b9e71_row16_col0, #T_b9e71_row17_col0, #T_b9e71_row18_col0, #T_b9e71_row19_col0, #T_b9e71_row20_col0, #T_b9e71_row21_col0, #T_b9e71_row22_col0, #T_b9e71_row23_col0, #T_b9e71_row24_col0, #T_b9e71_row25_col0, #T_b9e71_row26_col0, #T_b9e71_row27_col0, #T_b9e71_row28_col0, #T_b9e71_row29_col0, #T_b9e71_row30_col0, #T_b9e71_row31_col0, #T_b9e71_row32_col0, #T_b9e71_row33_col0, #T_b9e71_row34_col0, #T_b9e71_row35_col0, #T_b9e71_row36_col0, #T_b9e71_row37_col0, #T_b9e71_row38_col0 {
#   padding: 10px;
# }
# #T_b9e71_row0_col1 {
#   background-color: #deebf2;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row0_col2 {
#   background-color: #fbd0b9;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row0_col3 {
#   background-color: #fbe3d4;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row1_col1, #T_b9e71_row4_col1, #T_b9e71_row36_col1 {
#   background-color: #c7e0ed;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row1_col2, #T_b9e71_row4_col3, #T_b9e71_row36_col3 {
#   background-color: #f5f6f7;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row1_col3 {
#   background-color: #e6eff4;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row2_col1 {
#   background-color: #bddbea;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row2_col2, #T_b9e71_row10_col1 {
#   background-color: #e7f0f4;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row2_col3 {
#   background-color: #dbeaf2;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row3_col1, #T_b9e71_row34_col1 {
#   background-color: #cfe4ef;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row3_col2, #T_b9e71_row8_col3, #T_b9e71_row10_col3, #T_b9e71_row34_col2, #T_b9e71_row36_col2 {
#   background-color: #f8f4f2;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row3_col3 {
#   background-color: #f2f5f6;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row4_col2, #T_b9e71_row6_col3, #T_b9e71_row7_col3, #T_b9e71_row14_col3, #T_b9e71_row15_col3, #T_b9e71_row17_col3, #T_b9e71_row18_col3, #T_b9e71_row19_col3, #T_b9e71_row27_col3, #T_b9e71_row29_col3, #T_b9e71_row38_col3 {
#   background-color: #f7f5f4;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row5_col1, #T_b9e71_row6_col1, #T_b9e71_row7_col1, #T_b9e71_row8_col1, #T_b9e71_row9_col1, #T_b9e71_row16_col1, #T_b9e71_row17_col1, #T_b9e71_row18_col1, #T_b9e71_row29_col1, #T_b9e71_row38_col1 {
#   background-color: #d2e6f0;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row5_col2, #T_b9e71_row5_col3, #T_b9e71_row8_col2, #T_b9e71_row9_col2, #T_b9e71_row12_col3 {
#   background-color: #f9f0eb;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row6_col2, #T_b9e71_row7_col2, #T_b9e71_row10_col2, #T_b9e71_row12_col2, #T_b9e71_row14_col2, #T_b9e71_row16_col2, #T_b9e71_row17_col2, #T_b9e71_row18_col2, #T_b9e71_row27_col2, #T_b9e71_row29_col2, #T_b9e71_row38_col2 {
#   background-color: #f8f1ed;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row9_col3, #T_b9e71_row23_col3 {
#   background-color: #f8f3f0;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row11_col1, #T_b9e71_row26_col1, #T_b9e71_row31_col2 {
#   background-color: #acd2e5;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row11_col2 {
#   background-color: #e98b6e;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b9e71_row11_col3 {
#   background-color: #fddcc9;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row12_col1, #T_b9e71_row23_col1 {
#   background-color: #d4e6f1;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row13_col1 {
#   background-color: #d5e7f1;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row13_col2 {
#   background-color: #f9eee7;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row13_col3, #T_b9e71_row23_col2 {
#   background-color: #f9efe9;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row14_col1, #T_b9e71_row15_col1, #T_b9e71_row35_col1 {
#   background-color: #d1e5f0;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row15_col2, #T_b9e71_row35_col2, #T_b9e71_row37_col2 {
#   background-color: #f8f2ef;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row16_col3, #T_b9e71_row28_col2, #T_b9e71_row35_col3, #T_b9e71_row37_col3 {
#   background-color: #f7f6f6;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row19_col1 {
#   background-color: #a2cde3;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row19_col2 {
#   background-color: #ef9979;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row20_col1, #T_b9e71_row30_col2, #T_b9e71_row30_col3 {
#   background-color: #053061;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b9e71_row20_col2 {
#   background-color: #3681ba;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b9e71_row20_col3 {
#   background-color: #8ac0db;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row21_col1, #T_b9e71_row21_col2, #T_b9e71_row21_col3 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b9e71_row22_col1 {
#   background-color: #d8e9f1;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row22_col2, #T_b9e71_row22_col3 {
#   background-color: #faeae1;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row24_col1 {
#   background-color: #fdddcb;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row24_col2 {
#   background-color: #f7b596;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row24_col3 {
#   background-color: #c53e3d;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b9e71_row25_col1, #T_b9e71_row26_col2 {
#   background-color: #93c6de;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row25_col2 {
#   background-color: #337eb8;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b9e71_row25_col3, #T_b9e71_row32_col2 {
#   background-color: #98c8e0;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row26_col3, #T_b9e71_row28_col3 {
#   background-color: #e1edf3;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row27_col1 {
#   background-color: #b3d6e8;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row28_col1 {
#   background-color: #a0cce2;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row30_col1 {
#   background-color: #408fc1;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b9e71_row31_col1 {
#   background-color: #96c7df;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row31_col3 {
#   background-color: #a9d1e5;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row32_col1 {
#   background-color: #3c8abe;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b9e71_row32_col3 {
#   background-color: #9bc9e0;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row33_col1 {
#   background-color: #1b5a9c;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b9e71_row33_col2 {
#   background-color: #2b73b3;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b9e71_row33_col3 {
#   background-color: #307ab6;
#   color: #f1f1f1;
#   padding: 10px;
# }
# #T_b9e71_row34_col3 {
#   background-color: #f6f7f7;
#   color: #000000;
#   padding: 10px;
# }
# #T_b9e71_row37_col1 {
#   background-color: #cce2ef;
#   color: #000000;
#   padding: 10px;
# }
# </style>
# <table id="T_b9e71_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Captions</th>
#       <th class="col_heading level0 col1" >Dec. 31, 2020</th>
#       <th class="col_heading level0 col2" >Dec. 31, 2019</th>
#       <th class="col_heading level0 col3" >Dec. 31, 2018</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9e71_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b9e71_row0_col0" class="data row0 col0" >Net loss</td>
#       <td id="T_b9e71_row0_col1" class="data row0 col1" >-100.00%</td>
#       <td id="T_b9e71_row0_col2" class="data row0 col2" >-100.00%</td>
#       <td id="T_b9e71_row0_col3" class="data row0 col3" >-100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_b9e71_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_b9e71_row1_col0" class="data row1 col0" >Depreciation and amortization</td>
#       <td id="T_b9e71_row1_col1" class="data row1 col1" >67.87%</td>
#       <td id="T_b9e71_row1_col2" class="data row1 col2" >28.64%</td>
#       <td id="T_b9e71_row1_col3" class="da
